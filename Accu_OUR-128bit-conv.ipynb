# %%
import argparse
import tqdm
from tqdm import tqdm_notebook as tq
import os, time, math, copy, random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from collections import namedtuple
import itertools

torch.set_printoptions(precision=8, linewidth=50000)
import warnings
warnings.filterwarnings(action='ignore')

# %%
BLACK	= '\033[30m'
RED		= '\033[31m'
GREEN	= '\033[32m'
YELLOW	= '\033[33m'
BLUE	= '\033[34m'
MAGENTA	= '\033[35m'
CYAN	= '\033[36m'
RESET	= '\033[0m'
SEL		= '\033[7m'

# %%
parser = argparse.ArgumentParser(description='fixed_mac')
parser.add_argument('--device', type=str, default='cpu', help='Device')
parser.add_argument('--full_bits', type=int, default=8, help='Number of Quantization Bits') # full bits
parser.add_argument('--frac_bits', type=int, default=3, help='Number of Quantization Bits') # fraction bits
parser.add_argument('--bBW', type=int, default=4, help='Number of bitwidth')
args = parser.parse_args(args=[])

# %%
class	fxp:
	def	__init__(self, bIn, iBWF):
		self.iFullBW	= len(bIn)
		self.iIntgBW	= self.iFullBW - iBWF
		self.bSign		= bIn[0]
		self.bIntg		= bIn[:self.iIntgBW]
		self.bFrac		= bIn[self.iIntgBW:]
		self.fFull		= 0
		try:
			for idx, bit in enumerate(bIn):
				if	idx == 0:
					self.fFull = self.fFull + int(bit,2) * -pow(2, self.iIntgBW - 1)
				else:
					self.fFull = self.fFull + int(bit,2) * pow(2, self.iIntgBW - 1 - idx)
		except:
			print(bIn)
		self.dispFull	= RED + self.bIntg + BLUE + self.bFrac + RESET
		return

# %%
class	flp2fix:
	def	__init__(self, fIn, iBW, iBWF):
		self.fMin		= - 2 ** (iBW - iBWF - 1)
		self.fMax		= (2 ** (iBW-1) - 1) * (2 ** -iBWF)
		self.fResol		= 2 ** -iBWF
		if fIn < self.fMin or fIn > self.fMax:
			print(f'({fIn}): Out of input range ({self.fMax}/{self.fMin}) during flp -> fix converting ')
		self.iBW		= iBW
		self.iBWI		= iBW - iBWF # integer
		self.iBWF		= iBWF # fraction

		self.iFLP2INT	= abs(int(fIn * 2 ** iBWF))
		if fIn < 0:
			self.iFLP2INT = 2 ** (iBW-1) - self.iFLP2INT

		if fIn >= 0:
			self.bFull = bin(self.iFLP2INT)[2:].rjust(iBW, '0')
		else:
			self.bFull = '1'+bin(self.iFLP2INT)[2:].rjust(iBW-1, '0')
			if len(self.bFull) > iBW:
				self.bFull = '0' * iBW

		self.cssFxp		= fxp(self.bFull, self.iBWF)
		self.bSign		= self.cssFxp.bSign
		self.bIntg		= self.cssFxp.bIntg
		self.bFrac		= self.cssFxp.bFrac
		self.fFull		= self.cssFxp.fFull
		return

# %%
iIN = random.uniform(-(2**(args.bBW)),0)
iA = flp2fix(5, args.full_bits, args.frac_bits).bFull
ibA = flp2fix(iIN, args.full_bits, args.frac_bits).bFull
print(iIN)
print(iA, ibA)
iB = fxp('010110010', args.frac_bits).fFull
print(iB)
# Out:
# -14.230670509877061
# 00101000 10001111
# 22.25

# %% [markdown]
# ## Integer -> Tow's complement Binary

# %%
def int2bin(iIn, iBW): # iBW : bit length = 16
    iBW		= iBW + 1
    if iIn >= 0:
	    bOut	= bin(iIn).replace('0b','').rjust(iBW, '0')
    else:
	    bOut	= bin(iIn & (pow(2,iBW)-1)).replace('0b','').rjust(iBW, '1')
    return bOut[1:] # magnitude : go into the comparator and compare with LFSR's output

# %%
int2bin(-5,4)
# Out:
# '1011'

# %% [markdown]
# ## XOR

# %%
def XOR(iA, iB):
	if iA != iB:
		oOUT = '1'
	else:
		oOUT = '0'
	return oOUT

# %% [markdown]
# ## LFSR

# %%
def LFSR(seed, flag, taps):
    sr, xor = seed, 0
    for t in taps:
        xor += int(sr[t-1])
    if xor%2 == 0.0:
        xor = 0
    else:
        xor = 1
    sr, xor = str(xor) + sr[:-1], 0
    if sr == flag[0]:
        return len(seed)*'0'
    else:
        return sr

# %% [markdown]
# ## Comparator

# %%
def COMP(iA, l_lfsr):
    for comp in range(0, len(l_lfsr)): #lfsrlist : 16개의 elements -> len = 16
        oA = '0'
        if abs(iA) > int(l_lfsr[comp],2):
            oA = '1'
        elif abs(iA) < int(l_lfsr[comp],2):
            oA = '0'
            
    return oA

# %% [markdown]
# ## SNG_Conventional

# %%
def SNG(bBW, iA): # bBW = 8

    cA = int2bin(iA, bBW)
    s_cA = cA[0]    
    oAlist = []
    l_lfsr = []
    ran = random.randint(1, pow(2,bBW-1)-1)
    ranZP = bBW-1-len(bin(ran).replace('0b',''))
    num = ranZP*'0'+bin(ran).replace('0b','')
    
    for lfsr in range (0, (2**(bBW-1))):
        if not l_lfsr:
            l_lfsr.append(num)
        else:
            l_lfsr.append(LFSR(l_lfsr[lfsr-1], l_lfsr, (7,6)))
            
        oAlist.append(COMP(iA, l_lfsr))
        
    Onum = oAlist.count('1')
    oAlist.insert(0, s_cA)
    sA = ''.join(oAlist)
#    print(l_lfsr)
        
    return sA

# %%
len(SNG(8,25))
# Out:
# 129

# %% [markdown]
# ## Inter-Blocks: Output Revision(OUR) Scheme

# %%
def pos(SN):
    return SN[0] == '0'
def neg(SN):
    return SN[0] == '1'
def counter(x):
    return x.count('1')

# %%
def gen_acclist(bBW, IN):
    A_list=[]
    acc_A=0
    acc_Alist=[]
    for i in range(0,2**(bBW-1)):
        A = 0
        for k in range(len(IN)):
            if IN[k][i] == '1':
                A += 1
        A_list.append(A)
        acc_A += A_list[i]
        acc_Alist.append(acc_A)     
    
    return acc_Alist

# %%
def gen_So(bBW, diff):
    So_list=[]
    Ao_list=[]
    global So
    for o in range(2**(bBW-1)):
        if o == 0:
            Ao = 0 # first A_o is fixed
            if diff[o] > 0:
                So = 1
            else:
                So = 0
            Ao_list.append(Ao)
            So_list.append(So)
        else:
            Ao += So_list[o-1]
            Ao_list.append(Ao)
            if diff[o] > Ao_list[o]:
                So = 1
            elif diff[o] <= Ao_list[o]:
                So = 0
            So_list.append(So)
    
    return So_list

# %%
def block(IN):
    BLOCK1=[]
    BLOCK2=[]
    BLOCK3=[]
    BLOCK4=[]
    BLOCK5=[]
    BLOCK6=[]
    BLOCK7=[]
    BLOCK8=[]
    for i in range(len(IN)):
        block1 = IN[i][1:17]
        block2 = IN[i][17:33]
        block3 = IN[i][33:49]
        block4 = IN[i][49:65]
        block5 = IN[i][65:81]
        block6 = IN[i][81:97]
        block7 = IN[i][97:113]
        block8 = IN[i][113:]
        BLOCK1.append(block1)
        BLOCK2.append(block2)
        BLOCK3.append(block3)
        BLOCK4.append(block4)
        BLOCK5.append(block5)
        BLOCK6.append(block6)
        BLOCK7.append(block7)
        BLOCK8.append(block8)
    return BLOCK1, BLOCK2, BLOCK3, BLOCK4, BLOCK5, BLOCK6, BLOCK7, BLOCK8

# %%
def OUR(cnt, bBW): # bBW = 8
    global diff1, diff2, diff3, diff4, diff5, diff6, diff7, diff8, sign
    gen_SN = []
#    output = []
    for i in range(0, 2**cnt):
        iA = random.randint(-64,63)
        SN = SNG(bBW,iA) 
        gen_SN.append(SN)
  
    # sorting random input bit-stream(positive/negative)
    pos_IN = list(filter(pos, gen_SN))
    neg_IN = list(filter(neg, gen_SN))

    # Block devision
    pBLOCK1, pBLOCK2, pBLOCK3, pBLOCK4, pBLOCK5, pBLOCK6, pBLOCK7, pBLOCK8 = block(pos_IN)
    nBLOCK1, nBLOCK2, nBLOCK3, nBLOCK4, nBLOCK5, nBLOCK6, nBLOCK7, nBLOCK8 = block(neg_IN)

    # generate list of number of accumulated 1s
    Ap1_list = gen_acclist(bBW-3, pBLOCK1)
    An1_list = gen_acclist(bBW-3, nBLOCK1)
    Ap2_list = gen_acclist(bBW-3, pBLOCK2)
    An2_list = gen_acclist(bBW-3, nBLOCK2)
    Ap3_list = gen_acclist(bBW-3, pBLOCK3)
    An3_list = gen_acclist(bBW-3, nBLOCK3)
    Ap4_list = gen_acclist(bBW-3, pBLOCK4)
    An4_list = gen_acclist(bBW-3, nBLOCK4)
    Ap5_list = gen_acclist(bBW-3, pBLOCK5)
    An5_list = gen_acclist(bBW-3, nBLOCK5)
    Ap6_list = gen_acclist(bBW-3, pBLOCK6)
    An6_list = gen_acclist(bBW-3, nBLOCK6)
    Ap7_list = gen_acclist(bBW-3, pBLOCK7)
    An7_list = gen_acclist(bBW-3, nBLOCK7)
    Ap8_list = gen_acclist(bBW-3, pBLOCK8)
    An8_list = gen_acclist(bBW-3, nBLOCK8)

    # determine sign of output
    if Ap1_list[-1]+Ap2_list[-1]+Ap3_list[-1]+Ap4_list[-1] > An1_list[-1]+An2_list[-1]+An3_list[-1]+An4_list[-1]:
        diff1 = [x-y for x,y in zip(Ap1_list, An1_list)]
        diff2 = [x-y for x,y in zip(Ap2_list, An2_list)]
        diff3 = [x-y for x,y in zip(Ap3_list, An3_list)]
        diff4 = [x-y for x,y in zip(Ap4_list, An4_list)]
        diff5 = [x-y for x,y in zip(Ap5_list, An5_list)]
        diff6 = [x-y for x,y in zip(Ap6_list, An6_list)]
        diff7 = [x-y for x,y in zip(Ap7_list, An7_list)]
        diff8 = [x-y for x,y in zip(Ap8_list, An8_list)]
        sign  = ['0']        
    elif Ap1_list[-1]+Ap2_list[-1]+Ap3_list[-1]+Ap4_list[-1] < An1_list[-1]+An2_list[-1]+An3_list[-1]+An4_list[-1]:
        diff1 = [x-y for x,y in zip(An1_list, Ap1_list)]
        diff2 = [x-y for x,y in zip(An2_list, Ap2_list)]
        diff3 = [x-y for x,y in zip(An3_list, Ap3_list)]
        diff4 = [x-y for x,y in zip(An4_list, Ap4_list)]
        diff5 = [x-y for x,y in zip(An5_list, Ap5_list)]
        diff6 = [x-y for x,y in zip(An6_list, Ap6_list)]
        diff7 = [x-y for x,y in zip(An7_list, Ap7_list)]
        diff8 = [x-y for x,y in zip(An8_list, Ap8_list)]
        sign  = ['1']
    
    So1 = gen_So(bBW-3, diff1)
    So2 = gen_So(bBW-3, diff2)
    So3 = gen_So(bBW-3, diff3)
    So4 = gen_So(bBW-3, diff4)
    So5 = gen_So(bBW-3, diff5)
    So6 = gen_So(bBW-3, diff6)
    So7 = gen_So(bBW-3, diff7)
    So8 = gen_So(bBW-3, diff8)
    So_list = So1 + So2 + So3 + So4 + So5 + So6 + So7 + So8

    result = list(map(str, So_list))
    tempout = ''.join(result)

    p = abs((Ap1_list[-1]+Ap2_list[-1]+Ap3_list[-1]+Ap4_list[-1]+Ap5_list[-1]+Ap6_list[-1]+Ap7_list[-1]+Ap8_list[-1])-(An1_list[-1]+An2_list[-1]+An3_list[-1]+An4_list[-1]+An5_list[-1]+An6_list[-1]+An7_list[-1]+An8_list[-1]))
    q = counter(tempout)

    p_list=[]
    q_list=[counter(tempout)]
    out=[]
    for k in range(2**(bBW-1)):
        p_list.append(p)
        if q < p:
            q += 1
            out.append('1')
        elif q > p:
            q -= 1
            out.append('0')
        else:
            q = p
            out.append(tempout[k])
        q_list.append(q)
    sout = sign + out
    output = ''.join(sout)
    
#    print("===========================================")
#    print(" Index : %s"%(i+1))
#    print("-------------------------------------------")
#    print("real output: {0}/{1}".format((Ap1_list[-1]+Ap2_list[-1]+Ap3_list[-1]+Ap4_list[-1]+Ap5_list[-1]+Ap6_list[-1]+Ap7_list[-1]+Ap8_list[-1])-(An1_list[-1]+An2_list[-1]+An3_list[-1]+An4_list[-1]+An5_list[-1]+An6_list[-1]+An7_list[-1]+An8_list[-1]),128))
#    print("cal output : {0}/{1}".format(counter(output[1:]),128))
#    print('positive input = {0}'.format(pos_IN), len(pos_IN[0]))
#    print('negative input = {0}'.format(neg_IN), len(neg_IN[0]))
#    print('pBLOCK1 = {0}'.format(pBLOCK1))
#    print('nBLOCK1 = {0}'.format(nBLOCK1))
#    print(Ap1_list, An1_list)
#    print('pBLOCK2 = {0}'.format(pBLOCK2))
#    print('nBLOCK2 = {0}'.format(nBLOCK2))
#    print(Ap2_list, An2_list)
#    print('pBLOCK3 = {0}'.format(pBLOCK3))
#    print('nBLOCK3 = {0}'.format(nBLOCK3))
#    print(Ap3_list, An3_list)
#    print('pBLOCK4 = {0}'.format(pBLOCK4))
#    print('nBLOCK4 = {0}'.format(nBLOCK4))
#    print(Ap4_list, An4_list)
#    print('pBLOCK5 = {0}'.format(pBLOCK5))
#    print('nBLOCK5 = {0}'.format(nBLOCK5))
#    print(Ap5_list, An5_list)
#    print('pBLOCK6 = {0}'.format(pBLOCK6))
#    print('nBLOCK6 = {0}'.format(nBLOCK6))
#    print(Ap6_list, An6_list)
#    print('pBLOCK7 = {0}'.format(pBLOCK7))
#    print('nBLOCK7 = {0}'.format(nBLOCK7))
#    print(Ap7_list, An7_list)
#    print('pBLOCK8 = {0}'.format(pBLOCK8))
#    print('nBLOCK8 = {0}'.format(nBLOCK8))
#    print(Ap8_list, An8_list)
#    print(So1, So2, So3, So4)
#    print(tempout)
#    print(p_list)
#    print(q_list)
#    print(output)
#    print("===========================================")

    return output, counter(output[1:]), p

# %%
OUR(3,8)
# Out:
# ('011111111111111110001111111100011000000010000000000101111111111110100101111100100111111110111110110000000000001100000000111111111',
#  74,
#  83)

# %%
n = 0
k = 0
mse = 0
for i in range(1000):
    result, n_result, p = OUR(4,8)
    if p > 128:
        #print("intra-Block module result is: overflow!")
        k += 1
        #continue
    
    else:
        print("===========================================")
        print(" Index : %s"%(i+1))
        print("-------------------------------------------")
        print("intra-Block module result is: {0}/128".format(counter(result[1:])))
        print("real accumulation result is : {0}/128".format(p))
        print("===========================================")
        Error = abs(counter(result[1:])/128-p/128)*100
        if Error <= 5:
            n += 1
           
        #mse += pow((counter(result[1:])-p)/128,2)
        
#MSE = mse/(100-k)
#print(mse)
#print("128-bit's MSE is: {0}".format(MSE))
print("Accuracy is: {0}/{1}, {2}%".format(n, 1000-k, n/(1000-k)*100))
# Out:
# ===========================================
#  Index : 1
# -------------------------------------------
# intra-Block module result is: 53/128
# real accumulation result is : 43/128
# ===========================================
# ===========================================
#  Index : 2
# -------------------------------------------
# intra-Block module result is: 28/128
# real accumulation result is : 7/128
# ===========================================
# ===========================================
#  Index : 4
# -------------------------------------------
# intra-Block module result is: 22/128
# real accumulation result is : 3/128
# ===========================================
# ===========================================
#  Index : 5
# -------------------------------------------
# intra-Block module result is: 100/128
# real accumulation result is : 121/128
# ===========================================
# ===========================================
#  Index : 6
# -------------------------------------------
# intra-Block module result is: 63/128
# real accumulation result is : 47/128
# ===========================================
# ===========================================
#  Index : 7
# -------------------------------------------
# intra-Block module result is: 57/128
# real accumulation result is : 31/128
# ===========================================
# ===========================================
#  Index : 8
# -------------------------------------------
# intra-Block module result is: 68/128
# real accumulation result is : 84/128
# ===========================================
# ===========================================
#  Index : 10
# -------------------------------------------
# intra-Block module result is: 47/128
# real accumulation result is : 32/128
# ===========================================
# ===========================================
#  Index : 14
# -------------------------------------------
# intra-Block module result is: 18/128
# real accumulation result is : 0/128
# ===========================================
# ===========================================
#  Index : 15
# -------------------------------------------
# intra-Block module result is: 66/128
# real accumulation result is : 70/128
# ===========================================
# ===========================================
#  Index : 16
# -------------------------------------------
# intra-Block module result is: 102/128
# real accumulation result is : 116/128
# ===========================================
# ===========================================
#  Index : 18
# -------------------------------------------
# intra-Block module result is: 51/128
# real accumulation result is : 51/128
# ===========================================
# ===========================================
#  Index : 22
# -------------------------------------------
# intra-Block module result is: 93/128
# real accumulation result is : 113/128
# ===========================================
# ===========================================
#  Index : 23
# -------------------------------------------
# intra-Block module result is: 49/128
# real accumulation result is : 48/128
# ===========================================
# ===========================================
#  Index : 25
# -------------------------------------------
# intra-Block module result is: 99/128
# real accumulation result is : 109/128
# ===========================================
# ===========================================
#  Index : 27
# -------------------------------------------
# intra-Block module result is: 28/128
# real accumulation result is : 22/128
# ===========================================
# ===========================================
#  Index : 28
# -------------------------------------------
# intra-Block module result is: 39/128
# real accumulation result is : 40/128
# ===========================================
# ===========================================
#  Index : 29
# -------------------------------------------
# intra-Block module result is: 53/128
# real accumulation result is : 47/128
# ===========================================
# ===========================================
#  Index : 30
# -------------------------------------------
# intra-Block module result is: 36/128
# real accumulation result is : 12/128
# ===========================================
# ===========================================
#  Index : 31
# -------------------------------------------
# intra-Block module result is: 75/128
# real accumulation result is : 89/128
# ===========================================
# ===========================================
#  Index : 33
# -------------------------------------------
# intra-Block module result is: 35/128
# real accumulation result is : 15/128
# ===========================================
# ===========================================
#  Index : 35
# -------------------------------------------
# intra-Block module result is: 60/128
# real accumulation result is : 60/128
# ===========================================
# ===========================================
#  Index : 37
# -------------------------------------------
# intra-Block module result is: 18/128
# real accumulation result is : 13/128
# ===========================================
# ===========================================
#  Index : 38
# -------------------------------------------
# intra-Block module result is: 107/128
# real accumulation result is : 124/128
# ===========================================
# ===========================================
#  Index : 39
# -------------------------------------------
# intra-Block module result is: 24/128
# real accumulation result is : 18/128
# ===========================================
# ===========================================
#  Index : 40
# -------------------------------------------
# intra-Block module result is: 29/128
# real accumulation result is : 16/128
# ===========================================
# ===========================================
#  Index : 42
# -------------------------------------------
# intra-Block module result is: 29/128
# real accumulation result is : 21/128
# ===========================================
# ===========================================
#  Index : 43
# -------------------------------------------
# intra-Block module result is: 50/128
# real accumulation result is : 52/128
# ===========================================
# ===========================================
#  Index : 45
# -------------------------------------------
# intra-Block module result is: 32/128
# real accumulation result is : 33/128
# ===========================================
# ===========================================
#  Index : 49
# -------------------------------------------
# intra-Block module result is: 65/128
# real accumulation result is : 62/128
# ===========================================
# ===========================================
#  Index : 52
# -------------------------------------------
# intra-Block module result is: 79/128
# real accumulation result is : 83/128
# ===========================================
# ===========================================
#  Index : 53
# -------------------------------------------
# intra-Block module result is: 78/128
# real accumulation result is : 80/128
# ===========================================
# ===========================================
#  Index : 55
# -------------------------------------------
# intra-Block module result is: 63/128
# real accumulation result is : 51/128
# ===========================================
# ===========================================
#  Index : 56
# -------------------------------------------
# intra-Block module result is: 89/128
# real accumulation result is : 95/128
# ===========================================
# ===========================================
#  Index : 57
# -------------------------------------------
# intra-Block module result is: 97/128
# real accumulation result is : 105/128
# ===========================================
# ===========================================
#  Index : 58
# -------------------------------------------
# intra-Block module result is: 37/128
# real accumulation result is : 3/128
# ===========================================
# ===========================================
#  Index : 60
# -------------------------------------------
# intra-Block module result is: 107/128
# real accumulation result is : 125/128
# ===========================================
# ===========================================
#  Index : 62
# -------------------------------------------
# intra-Block module result is: 98/128
# real accumulation result is : 116/128
# ===========================================
# ===========================================
#  Index : 63
# -------------------------------------------
# intra-Block module result is: 31/128
# real accumulation result is : 3/128
# ===========================================
# ===========================================
#  Index : 64
# -------------------------------------------
# intra-Block module result is: 45/128
# real accumulation result is : 34/128
# ===========================================
# ===========================================
#  Index : 66
# -------------------------------------------
# intra-Block module result is: 31/128
# real accumulation result is : 25/128
# ===========================================
# ===========================================
#  Index : 67
# -------------------------------------------
# intra-Block module result is: 24/128
# real accumulation result is : 5/128
# ===========================================
# ===========================================
#  Index : 70
# -------------------------------------------
# intra-Block module result is: 52/128
# real accumulation result is : 47/128
# ===========================================
# ===========================================
#  Index : 71
# -------------------------------------------
# intra-Block module result is: 36/128
# real accumulation result is : 31/128
# ===========================================
# ===========================================
#  Index : 73
# -------------------------------------------
# intra-Block module result is: 25/128
# real accumulation result is : 15/128
# ===========================================
# ===========================================
#  Index : 74
# -------------------------------------------
# intra-Block module result is: 49/128
# real accumulation result is : 50/128
# ===========================================
# ===========================================
#  Index : 75
# -------------------------------------------
# intra-Block module result is: 77/128
# real accumulation result is : 77/128
# ===========================================
# ===========================================
#  Index : 76
# -------------------------------------------
# intra-Block module result is: 43/128
# real accumulation result is : 38/128
# ===========================================
# ===========================================
#  Index : 80
# -------------------------------------------
# intra-Block module result is: 88/128
# real accumulation result is : 105/128
# ===========================================
# ===========================================
#  Index : 81
# -------------------------------------------
# intra-Block module result is: 26/128
# real accumulation result is : 14/128
# ===========================================
# ===========================================
#  Index : 82
# -------------------------------------------
# intra-Block module result is: 29/128
# real accumulation result is : 21/128
# ===========================================
# ===========================================
#  Index : 84
# -------------------------------------------
# intra-Block module result is: 55/128
# real accumulation result is : 46/128
# ===========================================
# ===========================================
#  Index : 90
# -------------------------------------------
# intra-Block module result is: 26/128
# real accumulation result is : 26/128
# ===========================================
# ===========================================
#  Index : 94
# -------------------------------------------
# intra-Block module result is: 95/128
# real accumulation result is : 98/128
# ===========================================
# ===========================================
#  Index : 97
# -------------------------------------------
# intra-Block module result is: 80/128
# real accumulation result is : 80/128
# ===========================================
# ===========================================
#  Index : 98
# -------------------------------------------
# intra-Block module result is: 47/128
# real accumulation result is : 33/128
# ===========================================
# ===========================================
#  Index : 100
# -------------------------------------------
# intra-Block module result is: 87/128
# real accumulation result is : 91/128
# ===========================================
# ===========================================
#  Index : 103
# -------------------------------------------
# intra-Block module result is: 62/128
# real accumulation result is : 51/128
# ===========================================
# ===========================================
#  Index : 105
# -------------------------------------------
# intra-Block module result is: 28/128
# real accumulation result is : 25/128
# ===========================================
# ===========================================
#  Index : 106
# -------------------------------------------
# intra-Block module result is: 21/128
# real accumulation result is : 0/128
# ===========================================
# ===========================================
#  Index : 108
# -------------------------------------------
# intra-Block module result is: 24/128
# real accumulation result is : 12/128
# ===========================================
# ===========================================
#  Index : 112
# -------------------------------------------
# intra-Block module result is: 101/128
# real accumulation result is : 121/128
# ===========================================
# ===========================================
#  Index : 113
# -------------------------------------------
# intra-Block module result is: 32/128
# real accumulation result is : 22/128
# ===========================================
# ===========================================
#  Index : 114
# -------------------------------------------
# intra-Block module result is: 81/128
# real accumulation result is : 86/128
# ===========================================
# ===========================================
#  Index : 118
# -------------------------------------------
# intra-Block module result is: 109/128
# real accumulation result is : 120/128
# ===========================================
# ===========================================
#  Index : 119
# -------------------------------------------
# intra-Block module result is: 26/128
# real accumulation result is : 14/128
# ===========================================
# ===========================================
#  Index : 120
# -------------------------------------------
# intra-Block module result is: 63/128
# real accumulation result is : 60/128
# ===========================================
# ===========================================
#  Index : 121
# -------------------------------------------
# intra-Block module result is: 21/128
# real accumulation result is : 12/128
# ===========================================
# ===========================================
#  Index : 122
# -------------------------------------------
# intra-Block module result is: 22/128
# real accumulation result is : 3/128
# ===========================================
# ===========================================
#  Index : 123
# -------------------------------------------
# intra-Block module result is: 40/128
# real accumulation result is : 61/128
# ===========================================
# ===========================================
#  Index : 124
# -------------------------------------------
# intra-Block module result is: 19/128
# real accumulation result is : 4/128
# ===========================================
# ===========================================
#  Index : 125
# -------------------------------------------
# intra-Block module result is: 79/128
# real accumulation result is : 82/128
# ===========================================
# ===========================================
#  Index : 126
# -------------------------------------------
# intra-Block module result is: 108/128
# real accumulation result is : 121/128
# ===========================================
# ===========================================
#  Index : 127
# -------------------------------------------
# intra-Block module result is: 24/128
# real accumulation result is : 2/128
# ===========================================
# ===========================================
#  Index : 129
# -------------------------------------------
# intra-Block module result is: 18/128
# real accumulation result is : 3/128
# ===========================================
# ===========================================
#  Index : 131
# -------------------------------------------
# intra-Block module result is: 98/128
# real accumulation result is : 112/128
# ===========================================
# ===========================================
#  Index : 132
# -------------------------------------------
# intra-Block module result is: 56/128
# real accumulation result is : 40/128
# ===========================================
# ===========================================
#  Index : 133
# -------------------------------------------
# intra-Block module result is: 95/128
# real accumulation result is : 116/128
# ===========================================
# ===========================================
#  Index : 134
# -------------------------------------------
# intra-Block module result is: 72/128
# real accumulation result is : 72/128
# ===========================================
# ===========================================
#  Index : 135
# -------------------------------------------
# intra-Block module result is: 48/128
# real accumulation result is : 47/128
# ===========================================
# ===========================================
#  Index : 137
# -------------------------------------------
# intra-Block module result is: 43/128
# real accumulation result is : 40/128
# ===========================================
# ===========================================
#  Index : 140
# -------------------------------------------
# intra-Block module result is: 69/128
# real accumulation result is : 69/128
# ===========================================
# ===========================================
#  Index : 142
# -------------------------------------------
# intra-Block module result is: 97/128
# real accumulation result is : 119/128
# ===========================================
# ===========================================
#  Index : 143
# -------------------------------------------
# intra-Block module result is: 98/128
# real accumulation result is : 114/128
# ===========================================
# ===========================================
#  Index : 147
# -------------------------------------------
# intra-Block module result is: 39/128
# real accumulation result is : 34/128
# ===========================================
# ===========================================
#  Index : 148
# -------------------------------------------
# intra-Block module result is: 78/128
# real accumulation result is : 85/128
# ===========================================
# ===========================================
#  Index : 150
# -------------------------------------------
# intra-Block module result is: 88/128
# real accumulation result is : 102/128
# ===========================================
# ===========================================
#  Index : 152
# -------------------------------------------
# intra-Block module result is: 44/128
# real accumulation result is : 40/128
# ===========================================
# ===========================================
#  Index : 153
# -------------------------------------------
# intra-Block module result is: 37/128
# real accumulation result is : 27/128
# ===========================================
# ===========================================
#  Index : 154
# -------------------------------------------
# intra-Block module result is: 28/128
# real accumulation result is : 13/128
# ===========================================
# ===========================================
#  Index : 155
# -------------------------------------------
# intra-Block module result is: 60/128
# real accumulation result is : 60/128
# ===========================================
# ===========================================
#  Index : 156
# -------------------------------------------
# intra-Block module result is: 41/128
# real accumulation result is : 46/128
# ===========================================
# ===========================================
#  Index : 158
# -------------------------------------------
# intra-Block module result is: 81/128
# real accumulation result is : 81/128
# ===========================================
# ===========================================
#  Index : 159
# -------------------------------------------
# intra-Block module result is: 56/128
# real accumulation result is : 46/128
# ===========================================
# ===========================================
#  Index : 160
# -------------------------------------------
# intra-Block module result is: 65/128
# real accumulation result is : 69/128
# ===========================================
# ===========================================
#  Index : 161
# -------------------------------------------
# intra-Block module result is: 84/128
# real accumulation result is : 88/128
# ===========================================
# ===========================================
#  Index : 164
# -------------------------------------------
# intra-Block module result is: 33/128
# real accumulation result is : 4/128
# ===========================================
# ===========================================
#  Index : 166
# -------------------------------------------
# intra-Block module result is: 77/128
# real accumulation result is : 77/128
# ===========================================
# ===========================================
#  Index : 167
# -------------------------------------------
# intra-Block module result is: 42/128
# real accumulation result is : 42/128
# ===========================================
# ===========================================
#  Index : 168
# -------------------------------------------
# intra-Block module result is: 28/128
# real accumulation result is : 17/128
# ===========================================
# ===========================================
#  Index : 170
# -------------------------------------------
# intra-Block module result is: 92/128
# real accumulation result is : 110/128
# ===========================================
# ===========================================
#  Index : 171
# -------------------------------------------
# intra-Block module result is: 76/128
# real accumulation result is : 88/128
# ===========================================
# ===========================================
#  Index : 174
# -------------------------------------------
# intra-Block module result is: 102/128
# real accumulation result is : 124/128
# ===========================================
# ===========================================
#  Index : 175
# -------------------------------------------
# intra-Block module result is: 22/128
# real accumulation result is : 12/128
# ===========================================
# ===========================================
#  Index : 177
# -------------------------------------------
# intra-Block module result is: 56/128
# real accumulation result is : 44/128
# ===========================================
# ===========================================
#  Index : 179
# -------------------------------------------
# intra-Block module result is: 48/128
# real accumulation result is : 49/128
# ===========================================
# ===========================================
#  Index : 180
# -------------------------------------------
# intra-Block module result is: 79/128
# real accumulation result is : 95/128
# ===========================================
# ===========================================
#  Index : 182
# -------------------------------------------
# intra-Block module result is: 44/128
# real accumulation result is : 28/128
# ===========================================
# ===========================================
#  Index : 183
# -------------------------------------------
# intra-Block module result is: 55/128
# real accumulation result is : 49/128
# ===========================================
# ===========================================
#  Index : 186
# -------------------------------------------
# intra-Block module result is: 91/128
# real accumulation result is : 103/128
# ===========================================
# ===========================================
#  Index : 189
# -------------------------------------------
# intra-Block module result is: 59/128
# real accumulation result is : 68/128
# ===========================================
# ===========================================
#  Index : 190
# -------------------------------------------
# intra-Block module result is: 66/128
# real accumulation result is : 72/128
# ===========================================
# ===========================================
#  Index : 193
# -------------------------------------------
# intra-Block module result is: 54/128
# real accumulation result is : 54/128
# ===========================================
# ===========================================
#  Index : 195
# -------------------------------------------
# intra-Block module result is: 94/128
# real accumulation result is : 114/128
# ===========================================
# ===========================================
#  Index : 197
# -------------------------------------------
# intra-Block module result is: 89/128
# real accumulation result is : 115/128
# ===========================================
# ===========================================
#  Index : 198
# -------------------------------------------
# intra-Block module result is: 18/128
# real accumulation result is : 15/128
# ===========================================
# ===========================================
#  Index : 199
# -------------------------------------------
# intra-Block module result is: 38/128
# real accumulation result is : 32/128
# ===========================================
# ===========================================
#  Index : 200
# -------------------------------------------
# intra-Block module result is: 83/128
# real accumulation result is : 85/128
# ===========================================
# ===========================================
#  Index : 201
# -------------------------------------------
# intra-Block module result is: 27/128
# real accumulation result is : 9/128
# ===========================================
# ===========================================
#  Index : 202
# -------------------------------------------
# intra-Block module result is: 61/128
# real accumulation result is : 81/128
# ===========================================
# ===========================================
#  Index : 203
# -------------------------------------------
# intra-Block module result is: 66/128
# real accumulation result is : 66/128
# ===========================================
# ===========================================
#  Index : 204
# -------------------------------------------
# intra-Block module result is: 89/128
# real accumulation result is : 99/128
# ===========================================
# ===========================================
#  Index : 206
# -------------------------------------------
# intra-Block module result is: 89/128
# real accumulation result is : 119/128
# ===========================================
# ===========================================
#  Index : 208
# -------------------------------------------
# intra-Block module result is: 75/128
# real accumulation result is : 90/128
# ===========================================
# ===========================================
#  Index : 210
# -------------------------------------------
# intra-Block module result is: 58/128
# real accumulation result is : 59/128
# ===========================================
# ===========================================
#  Index : 211
# -------------------------------------------
# intra-Block module result is: 71/128
# real accumulation result is : 86/128
# ===========================================
# ===========================================
#  Index : 212
# -------------------------------------------
# intra-Block module result is: 67/128
# real accumulation result is : 72/128
# ===========================================
# ===========================================
#  Index : 213
# -------------------------------------------
# intra-Block module result is: 81/128
# real accumulation result is : 88/128
# ===========================================
# ===========================================
#  Index : 214
# -------------------------------------------
# intra-Block module result is: 25/128
# real accumulation result is : 23/128
# ===========================================
# ===========================================
#  Index : 215
# -------------------------------------------
# intra-Block module result is: 73/128
# real accumulation result is : 75/128
# ===========================================
# ===========================================
#  Index : 216
# -------------------------------------------
# intra-Block module result is: 62/128
# real accumulation result is : 64/128
# ===========================================
# ===========================================
#  Index : 217
# -------------------------------------------
# intra-Block module result is: 37/128
# real accumulation result is : 7/128
# ===========================================
# ===========================================
#  Index : 218
# -------------------------------------------
# intra-Block module result is: 100/128
# real accumulation result is : 111/128
# ===========================================
# ===========================================
#  Index : 220
# -------------------------------------------
# intra-Block module result is: 78/128
# real accumulation result is : 94/128
# ===========================================
# ===========================================
#  Index : 222
# -------------------------------------------
# intra-Block module result is: 35/128
# real accumulation result is : 21/128
# ===========================================
# ===========================================
#  Index : 225
# -------------------------------------------
# intra-Block module result is: 45/128
# real accumulation result is : 28/128
# ===========================================
# ===========================================
#  Index : 226
# -------------------------------------------
# intra-Block module result is: 60/128
# real accumulation result is : 58/128
# ===========================================
# ===========================================
#  Index : 227
# -------------------------------------------
# intra-Block module result is: 85/128
# real accumulation result is : 85/128
# ===========================================
# ===========================================
#  Index : 229
# -------------------------------------------
# intra-Block module result is: 32/128
# real accumulation result is : 13/128
# ===========================================
# ===========================================
#  Index : 231
# -------------------------------------------
# intra-Block module result is: 75/128
# real accumulation result is : 85/128
# ===========================================
# ===========================================
#  Index : 232
# -------------------------------------------
# intra-Block module result is: 92/128
# real accumulation result is : 120/128
# ===========================================
# ===========================================
#  Index : 234
# -------------------------------------------
# intra-Block module result is: 58/128
# real accumulation result is : 54/128
# ===========================================
# ===========================================
#  Index : 235
# -------------------------------------------
# intra-Block module result is: 30/128
# real accumulation result is : 7/128
# ===========================================
# ===========================================
#  Index : 236
# -------------------------------------------
# intra-Block module result is: 86/128
# real accumulation result is : 95/128
# ===========================================
# ===========================================
#  Index : 237
# -------------------------------------------
# intra-Block module result is: 22/128
# real accumulation result is : 6/128
# ===========================================
# ===========================================
#  Index : 238
# -------------------------------------------
# intra-Block module result is: 114/128
# real accumulation result is : 127/128
# ===========================================
# ===========================================
#  Index : 239
# -------------------------------------------
# intra-Block module result is: 25/128
# real accumulation result is : 6/128
# ===========================================
# ===========================================
#  Index : 240
# -------------------------------------------
# intra-Block module result is: 107/128
# real accumulation result is : 116/128
# ===========================================
# ===========================================
#  Index : 241
# -------------------------------------------
# intra-Block module result is: 39/128
# real accumulation result is : 19/128
# ===========================================
# ===========================================
#  Index : 242
# -------------------------------------------
# intra-Block module result is: 63/128
# real accumulation result is : 64/128
# ===========================================
# ===========================================
#  Index : 244
# -------------------------------------------
# intra-Block module result is: 58/128
# real accumulation result is : 56/128
# ===========================================
# ===========================================
#  Index : 246
# -------------------------------------------
# intra-Block module result is: 62/128
# real accumulation result is : 67/128
# ===========================================
# ===========================================
#  Index : 247
# -------------------------------------------
# intra-Block module result is: 70/128
# real accumulation result is : 70/128
# ===========================================
# ===========================================
#  Index : 248
# -------------------------------------------
# intra-Block module result is: 33/128
# real accumulation result is : 22/128
# ===========================================
# ===========================================
#  Index : 251
# -------------------------------------------
# intra-Block module result is: 25/128
# real accumulation result is : 6/128
# ===========================================
# ===========================================
#  Index : 252
# -------------------------------------------
# intra-Block module result is: 83/128
# real accumulation result is : 90/128
# ===========================================
# ===========================================
#  Index : 253
# -------------------------------------------
# intra-Block module result is: 83/128
# real accumulation result is : 101/128
# ===========================================
# ===========================================
#  Index : 255
# -------------------------------------------
# intra-Block module result is: 33/128
# real accumulation result is : 4/128
# ===========================================
# ===========================================
#  Index : 258
# -------------------------------------------
# intra-Block module result is: 63/128
# real accumulation result is : 70/128
# ===========================================
# ===========================================
#  Index : 263
# -------------------------------------------
# intra-Block module result is: 55/128
# real accumulation result is : 55/128
# ===========================================
# ===========================================
#  Index : 264
# -------------------------------------------
# intra-Block module result is: 103/128
# real accumulation result is : 104/128
# ===========================================
# ===========================================
#  Index : 265
# -------------------------------------------
# intra-Block module result is: 27/128
# real accumulation result is : 32/128
# ===========================================
# ===========================================
#  Index : 266
# -------------------------------------------
# intra-Block module result is: 92/128
# real accumulation result is : 108/128
# ===========================================
# ===========================================
#  Index : 268
# -------------------------------------------
# intra-Block module result is: 40/128
# real accumulation result is : 36/128
# ===========================================
# ===========================================
#  Index : 269
# -------------------------------------------
# intra-Block module result is: 69/128
# real accumulation result is : 70/128
# ===========================================
# ===========================================
#  Index : 270
# -------------------------------------------
# intra-Block module result is: 23/128
# real accumulation result is : 0/128
# ===========================================
# ===========================================
#  Index : 271
# -------------------------------------------
# intra-Block module result is: 57/128
# real accumulation result is : 47/128
# ===========================================
# ===========================================
#  Index : 273
# -------------------------------------------
# intra-Block module result is: 50/128
# real accumulation result is : 50/128
# ===========================================
# ===========================================
#  Index : 275
# -------------------------------------------
# intra-Block module result is: 70/128
# real accumulation result is : 80/128
# ===========================================
# ===========================================
#  Index : 276
# -------------------------------------------
# intra-Block module result is: 36/128
# real accumulation result is : 30/128
# ===========================================
# ===========================================
#  Index : 277
# -------------------------------------------
# intra-Block module result is: 96/128
# real accumulation result is : 102/128
# ===========================================
# ===========================================
#  Index : 278
# -------------------------------------------
# intra-Block module result is: 80/128
# real accumulation result is : 84/128
# ===========================================
# ===========================================
#  Index : 282
# -------------------------------------------
# intra-Block module result is: 61/128
# real accumulation result is : 61/128
# ===========================================
# ===========================================
#  Index : 284
# -------------------------------------------
# intra-Block module result is: 99/128
# real accumulation result is : 126/128
# ===========================================
# ===========================================
#  Index : 285
# -------------------------------------------
# intra-Block module result is: 87/128
# real accumulation result is : 115/128
# ===========================================
# ===========================================
#  Index : 287
# -------------------------------------------
# intra-Block module result is: 26/128
# real accumulation result is : 26/128
# ===========================================
# ===========================================
#  Index : 288
# -------------------------------------------
# intra-Block module result is: 48/128
# real accumulation result is : 38/128
# ===========================================
# ===========================================
#  Index : 289
# -------------------------------------------
# intra-Block module result is: 69/128
# real accumulation result is : 74/128
# ===========================================
# ===========================================
#  Index : 290
# -------------------------------------------
# intra-Block module result is: 102/128
# real accumulation result is : 110/128
# ===========================================
# ===========================================
#  Index : 291
# -------------------------------------------
# intra-Block module result is: 102/128
# real accumulation result is : 124/128
# ===========================================
# ===========================================
#  Index : 292
# -------------------------------------------
# intra-Block module result is: 37/128
# real accumulation result is : 31/128
# ===========================================
# ===========================================
#  Index : 293
# -------------------------------------------
# intra-Block module result is: 83/128
# real accumulation result is : 96/128
# ===========================================
# ===========================================
#  Index : 294
# -------------------------------------------
# intra-Block module result is: 71/128
# real accumulation result is : 72/128
# ===========================================
# ===========================================
#  Index : 296
# -------------------------------------------
# intra-Block module result is: 61/128
# real accumulation result is : 51/128
# ===========================================
# ===========================================
#  Index : 297
# -------------------------------------------
# intra-Block module result is: 60/128
# real accumulation result is : 59/128
# ===========================================
# ===========================================
#  Index : 299
# -------------------------------------------
# intra-Block module result is: 72/128
# real accumulation result is : 86/128
# ===========================================
# ===========================================
#  Index : 300
# -------------------------------------------
# intra-Block module result is: 61/128
# real accumulation result is : 57/128
# ===========================================
# ===========================================
#  Index : 301
# -------------------------------------------
# intra-Block module result is: 96/128
# real accumulation result is : 106/128
# ===========================================
# ===========================================
#  Index : 303
# -------------------------------------------
# intra-Block module result is: 45/128
# real accumulation result is : 42/128
# ===========================================
# ===========================================
#  Index : 304
# -------------------------------------------
# intra-Block module result is: 38/128
# real accumulation result is : 24/128
# ===========================================
# ===========================================
#  Index : 306
# -------------------------------------------
# intra-Block module result is: 62/128
# real accumulation result is : 57/128
# ===========================================
# ===========================================
#  Index : 307
# -------------------------------------------
# intra-Block module result is: 86/128
# real accumulation result is : 86/128
# ===========================================
# ===========================================
#  Index : 308
# -------------------------------------------
# intra-Block module result is: 86/128
# real accumulation result is : 111/128
# ===========================================
# ===========================================
#  Index : 311
# -------------------------------------------
# intra-Block module result is: 83/128
# real accumulation result is : 83/128
# ===========================================
# ===========================================
#  Index : 313
# -------------------------------------------
# intra-Block module result is: 25/128
# real accumulation result is : 0/128
# ===========================================
# ===========================================
#  Index : 314
# -------------------------------------------
# intra-Block module result is: 24/128
# real accumulation result is : 14/128
# ===========================================
# ===========================================
#  Index : 315
# -------------------------------------------
# intra-Block module result is: 105/128
# real accumulation result is : 118/128
# ===========================================
# ===========================================
#  Index : 316
# -------------------------------------------
# intra-Block module result is: 57/128
# real accumulation result is : 54/128
# ===========================================
# ===========================================
#  Index : 318
# -------------------------------------------
# intra-Block module result is: 37/128
# real accumulation result is : 20/128
# ===========================================
# ===========================================
#  Index : 320
# -------------------------------------------
# intra-Block module result is: 103/128
# real accumulation result is : 127/128
# ===========================================
# ===========================================
#  Index : 321
# -------------------------------------------
# intra-Block module result is: 94/128
# real accumulation result is : 125/128
# ===========================================
# ===========================================
#  Index : 322
# -------------------------------------------
# intra-Block module result is: 110/128
# real accumulation result is : 124/128
# ===========================================
# ===========================================
#  Index : 323
# -------------------------------------------
# intra-Block module result is: 107/128
# real accumulation result is : 118/128
# ===========================================
# ===========================================
#  Index : 324
# -------------------------------------------
# intra-Block module result is: 77/128
# real accumulation result is : 80/128
# ===========================================
# ===========================================
#  Index : 325
# -------------------------------------------
# intra-Block module result is: 62/128
# real accumulation result is : 85/128
# ===========================================
# ===========================================
#  Index : 328
# -------------------------------------------
# intra-Block module result is: 38/128
# real accumulation result is : 30/128
# ===========================================
# ===========================================
#  Index : 329
# -------------------------------------------
# intra-Block module result is: 29/128
# real accumulation result is : 16/128
# ===========================================
# ===========================================
#  Index : 330
# -------------------------------------------
# intra-Block module result is: 89/128
# real accumulation result is : 112/128
# ===========================================
# ===========================================
#  Index : 331
# -------------------------------------------
# intra-Block module result is: 57/128
# real accumulation result is : 57/128
# ===========================================
# ===========================================
#  Index : 332
# -------------------------------------------
# intra-Block module result is: 22/128
# real accumulation result is : 5/128
# ===========================================
# ===========================================
#  Index : 333
# -------------------------------------------
# intra-Block module result is: 98/128
# real accumulation result is : 110/128
# ===========================================
# ===========================================
#  Index : 334
# -------------------------------------------
# intra-Block module result is: 22/128
# real accumulation result is : 11/128
# ===========================================
# ===========================================
#  Index : 335
# -------------------------------------------
# intra-Block module result is: 70/128
# real accumulation result is : 81/128
# ===========================================
# ===========================================
#  Index : 336
# -------------------------------------------
# intra-Block module result is: 65/128
# real accumulation result is : 62/128
# ===========================================
# ===========================================
#  Index : 337
# -------------------------------------------
# intra-Block module result is: 47/128
# real accumulation result is : 41/128
# ===========================================
# ===========================================
#  Index : 338
# -------------------------------------------
# intra-Block module result is: 93/128
# real accumulation result is : 104/128
# ===========================================
# ===========================================
#  Index : 340
# -------------------------------------------
# intra-Block module result is: 38/128
# real accumulation result is : 42/128
# ===========================================
# ===========================================
#  Index : 341
# -------------------------------------------
# intra-Block module result is: 59/128
# real accumulation result is : 59/128
# ===========================================
# ===========================================
#  Index : 343
# -------------------------------------------
# intra-Block module result is: 89/128
# real accumulation result is : 104/128
# ===========================================
# ===========================================
#  Index : 344
# ...
#  Index : 876
# -------------------------------------------
# intra-Block module result is: 79/128
# real accumulation result is : 96/128
# ===========================================
# ===========================================
#  Index : 877
# -------------------------------------------
# intra-Block module result is: 92/128
# real accumulation result is : 107/128
# ===========================================
# ===========================================
#  Index : 878
# -------------------------------------------
# intra-Block module result is: 77/128
# real accumulation result is : 81/128
# ===========================================
# ===========================================
#  Index : 881
# -------------------------------------------
# intra-Block module result is: 114/128
# real accumulation result is : 120/128
# ===========================================
# ===========================================
#  Index : 882
# -------------------------------------------
# intra-Block module result is: 46/128
# real accumulation result is : 42/128
# ===========================================
# ===========================================
#  Index : 884
# -------------------------------------------
# intra-Block module result is: 35/128
# real accumulation result is : 34/128
# ===========================================
# ===========================================
#  Index : 885
# -------------------------------------------
# intra-Block module result is: 61/128
# real accumulation result is : 46/128
# ===========================================
# ===========================================
#  Index : 886
# -------------------------------------------
# intra-Block module result is: 93/128
# real accumulation result is : 106/128
# ===========================================
# ===========================================
#  Index : 887
# -------------------------------------------
# intra-Block module result is: 98/128
# real accumulation result is : 108/128
# ===========================================
# ===========================================
#  Index : 888
# -------------------------------------------
# intra-Block module result is: 81/128
# real accumulation result is : 81/128
# ===========================================
# ===========================================
#  Index : 889
# -------------------------------------------
# intra-Block module result is: 71/128
# real accumulation result is : 96/128
# ===========================================
# ===========================================
#  Index : 890
# -------------------------------------------
# intra-Block module result is: 31/128
# real accumulation result is : 24/128
# ===========================================
# ===========================================
#  Index : 891
# -------------------------------------------
# intra-Block module result is: 65/128
# real accumulation result is : 66/128
# ===========================================
# ===========================================
#  Index : 893
# -------------------------------------------
# intra-Block module result is: 100/128
# real accumulation result is : 113/128
# ===========================================
# ===========================================
#  Index : 896
# -------------------------------------------
# intra-Block module result is: 16/128
# real accumulation result is : 4/128
# ===========================================
# ===========================================
#  Index : 897
# -------------------------------------------
# intra-Block module result is: 81/128
# real accumulation result is : 84/128
# ===========================================
# ===========================================
#  Index : 898
# -------------------------------------------
# intra-Block module result is: 64/128
# real accumulation result is : 61/128
# ===========================================
# ===========================================
#  Index : 899
# -------------------------------------------
# intra-Block module result is: 32/128
# real accumulation result is : 25/128
# ===========================================
# ===========================================
#  Index : 901
# -------------------------------------------
# intra-Block module result is: 77/128
# real accumulation result is : 77/128
# ===========================================
# ===========================================
#  Index : 902
# -------------------------------------------
# intra-Block module result is: 38/128
# real accumulation result is : 10/128
# ===========================================
# ===========================================
#  Index : 903
# -------------------------------------------
# intra-Block module result is: 86/128
# real accumulation result is : 102/128
# ===========================================
# ===========================================
#  Index : 904
# -------------------------------------------
# intra-Block module result is: 86/128
# real accumulation result is : 96/128
# ===========================================
# ===========================================
#  Index : 905
# -------------------------------------------
# intra-Block module result is: 75/128
# real accumulation result is : 84/128
# ===========================================
# ===========================================
#  Index : 906
# -------------------------------------------
# intra-Block module result is: 32/128
# real accumulation result is : 14/128
# ===========================================
# ===========================================
#  Index : 907
# -------------------------------------------
# intra-Block module result is: 50/128
# real accumulation result is : 46/128
# ===========================================
# ===========================================
#  Index : 909
# -------------------------------------------
# intra-Block module result is: 59/128
# real accumulation result is : 59/128
# ===========================================
# ===========================================
#  Index : 912
# -------------------------------------------
# intra-Block module result is: 95/128
# real accumulation result is : 110/128
# ===========================================
# ===========================================
#  Index : 914
# -------------------------------------------
# intra-Block module result is: 58/128
# real accumulation result is : 51/128
# ===========================================
# ===========================================
#  Index : 915
# -------------------------------------------
# intra-Block module result is: 76/128
# real accumulation result is : 92/128
# ===========================================
# ===========================================
#  Index : 916
# -------------------------------------------
# intra-Block module result is: 50/128
# real accumulation result is : 50/128
# ===========================================
# ===========================================
#  Index : 917
# -------------------------------------------
# intra-Block module result is: 96/128
# real accumulation result is : 118/128
# ===========================================
# ===========================================
#  Index : 919
# -------------------------------------------
# intra-Block module result is: 67/128
# real accumulation result is : 68/128
# ===========================================
# ===========================================
#  Index : 921
# -------------------------------------------
# intra-Block module result is: 31/128
# real accumulation result is : 6/128
# ===========================================
# ===========================================
#  Index : 923
# -------------------------------------------
# intra-Block module result is: 67/128
# real accumulation result is : 68/128
# ===========================================
# ===========================================
#  Index : 925
# -------------------------------------------
# intra-Block module result is: 25/128
# real accumulation result is : 25/128
# ===========================================
# ===========================================
#  Index : 928
# -------------------------------------------
# intra-Block module result is: 90/128
# real accumulation result is : 104/128
# ===========================================
# ===========================================
#  Index : 935
# -------------------------------------------
# intra-Block module result is: 98/128
# real accumulation result is : 112/128
# ===========================================
# ===========================================
#  Index : 937
# -------------------------------------------
# intra-Block module result is: 56/128
# real accumulation result is : 58/128
# ===========================================
# ===========================================
#  Index : 939
# -------------------------------------------
# intra-Block module result is: 51/128
# real accumulation result is : 44/128
# ===========================================
# ===========================================
#  Index : 945
# -------------------------------------------
# intra-Block module result is: 93/128
# real accumulation result is : 114/128
# ===========================================
# ===========================================
#  Index : 950
# -------------------------------------------
# intra-Block module result is: 25/128
# real accumulation result is : 4/128
# ===========================================
# ===========================================
#  Index : 955
# -------------------------------------------
# intra-Block module result is: 19/128
# real accumulation result is : 17/128
# ===========================================
# ===========================================
#  Index : 957
# -------------------------------------------
# intra-Block module result is: 48/128
# real accumulation result is : 54/128
# ===========================================
# ===========================================
#  Index : 959
# -------------------------------------------
# intra-Block module result is: 99/128
# real accumulation result is : 114/128
# ===========================================
# ===========================================
#  Index : 962
# -------------------------------------------
# intra-Block module result is: 75/128
# real accumulation result is : 78/128
# ===========================================
# ===========================================
#  Index : 964
# -------------------------------------------
# intra-Block module result is: 63/128
# real accumulation result is : 63/128
# ===========================================
# ===========================================
#  Index : 965
# -------------------------------------------
# intra-Block module result is: 98/128
# real accumulation result is : 116/128
# ===========================================
# ===========================================
#  Index : 967
# -------------------------------------------
# intra-Block module result is: 55/128
# real accumulation result is : 36/128
# ===========================================
# ===========================================
#  Index : 969
# -------------------------------------------
# intra-Block module result is: 93/128
# real accumulation result is : 96/128
# ===========================================
# ===========================================
#  Index : 970
# -------------------------------------------
# intra-Block module result is: 99/128
# real accumulation result is : 116/128
# ===========================================
# ===========================================
#  Index : 971
# -------------------------------------------
# intra-Block module result is: 64/128
# real accumulation result is : 72/128
# ===========================================
# ===========================================
#  Index : 973
# -------------------------------------------
# intra-Block module result is: 39/128
# real accumulation result is : 26/128
# ===========================================
# ===========================================
#  Index : 974
# -------------------------------------------
# intra-Block module result is: 22/128
# real accumulation result is : 10/128
# ===========================================
# ===========================================
#  Index : 975
# -------------------------------------------
# intra-Block module result is: 58/128
# real accumulation result is : 59/128
# ===========================================
# ===========================================
#  Index : 976
# -------------------------------------------
# intra-Block module result is: 48/128
# real accumulation result is : 48/128
# ===========================================
# ===========================================
#  Index : 978
# -------------------------------------------
# intra-Block module result is: 39/128
# real accumulation result is : 4/128
# ===========================================
# ===========================================
#  Index : 979
# -------------------------------------------
# intra-Block module result is: 62/128
# real accumulation result is : 60/128
# ===========================================
# ===========================================
#  Index : 980
# -------------------------------------------
# intra-Block module result is: 87/128
# real accumulation result is : 116/128
# ===========================================
# ===========================================
#  Index : 981
# -------------------------------------------
# intra-Block module result is: 95/128
# real accumulation result is : 105/128
# ===========================================
# ===========================================
#  Index : 982
# -------------------------------------------
# intra-Block module result is: 28/128
# real accumulation result is : 25/128
# ===========================================
# ===========================================
#  Index : 983
# -------------------------------------------
# intra-Block module result is: 113/128
# real accumulation result is : 127/128
# ===========================================
# ===========================================
#  Index : 984
# -------------------------------------------
# intra-Block module result is: 23/128
# real accumulation result is : 14/128
# ===========================================
# ===========================================
#  Index : 987
# -------------------------------------------
# intra-Block module result is: 22/128
# real accumulation result is : 1/128
# ===========================================
# ===========================================
#  Index : 988
# -------------------------------------------
# intra-Block module result is: 28/128
# real accumulation result is : 9/128
# ===========================================
# ===========================================
#  Index : 989
# -------------------------------------------
# intra-Block module result is: 82/128
# real accumulation result is : 95/128
# ===========================================
# ===========================================
#  Index : 990
# -------------------------------------------
# intra-Block module result is: 20/128
# real accumulation result is : 4/128
# ===========================================
# ===========================================
#  Index : 991
# -------------------------------------------
# intra-Block module result is: 95/128
# real accumulation result is : 112/128
# ===========================================
# ===========================================
#  Index : 993
# -------------------------------------------
# intra-Block module result is: 28/128
# real accumulation result is : 5/128
# ===========================================
# ===========================================
#  Index : 994
# -------------------------------------------
# intra-Block module result is: 67/128
# real accumulation result is : 75/128
# ===========================================
# ===========================================
#  Index : 995
# -------------------------------------------
# intra-Block module result is: 98/128
# real accumulation result is : 124/128
# ===========================================
# ===========================================
#  Index : 997
# -------------------------------------------
# intra-Block module result is: 45/128
# real accumulation result is : 29/128
# ===========================================
# ===========================================
#  Index : 998
# -------------------------------------------
# intra-Block module result is: 92/128
# real accumulation result is : 124/128
# ===========================================
# ===========================================
#  Index : 1000
# -------------------------------------------
# intra-Block module result is: 80/128
# real accumulation result is : 80/128
# ===========================================
# Accuracy is: 232/616, 37.66233766233766%
